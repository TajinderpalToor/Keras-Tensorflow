# %% [markdown]
# Going through Tranfer Learning, Fine Tuning

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import tensorflow_hub as hub
#tensorflow hub is just a repository of trained machine learning models that are ready for fine tuning

# %%
#Pretrained models -- pretrained keras model

#random data -- the x matches the shape of input of the keras model we choose
x=tf.random.normal(shape=(5,299,299,3))
y=tf.constant([0,1,2,3,4])

#the include_top part just lets you remove th laste fully connected layer and get just the feature vectors so you can pass it to your own network
model=keras.applications.InceptionV3(include_top=True)
print(model.summary())

base_input= model.layers[0].input
base_outputs=model.layers[-2].output
#have 5 classes to sending output of second last fully connected layer to another dense layer which will give us the output cause the inception v3 doesnt specify a number of outputs
final_outputs=layers.Dense(5)(base_outputs)

new_model=keras.Model(inputs=base_input,outputs=final_outputs)

model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"],
)

model.fit(x,y,epochs=15,verbose=2)
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_282 (Conv2D)         (None, 149, 149, 32)         864       ['input_4[0][0]']
#
#  batch_normalization_282 (B  (None, 149, 149, 32)         96        ['conv2d_282[0][0]']
#  atchNormalization)
#
#  activation_282 (Activation  (None, 149, 149, 32)         0         ['batch_normalization_282[0][0
#  )                                                                  ]']
#
#  conv2d_283 (Conv2D)         (None, 147, 147, 32)         9216      ['activation_282[0][0]']
#
#  batch_normalization_283 (B  (None, 147, 147, 32)         96        ['conv2d_283[0][0]']
#  atchNormalization)
#
#  activation_283 (Activation  (None, 147, 147, 32)         0         ['batch_normalization_283[0][0
#  )                                                                  ]']
#
#  conv2d_284 (Conv2D)         (None, 147, 147, 64)         18432     ['activation_283[0][0]']
#
#  batch_normalization_284 (B  (None, 147, 147, 64)         192       ['conv2d_284[0][0]']
#  atchNormalization)
#
#  activation_284 (Activation  (None, 147, 147, 64)         0         ['batch_normalization_284[0][0
#  )                                                                  ]']
#
#  max_pooling2d_12 (MaxPooli  (None, 73, 73, 64)           0         ['activation_284[0][0]']
#  ng2D)
#
#  conv2d_285 (Conv2D)         (None, 73, 73, 80)           5120      ['max_pooling2d_12[0][0]']
#
#  batch_normalization_285 (B  (None, 73, 73, 80)           240       ['conv2d_285[0][0]']
#  atchNormalization)
#
#  activation_285 (Activation  (None, 73, 73, 80)           0         ['batch_normalization_285[0][0
#  )                                                                  ]']
#
#  conv2d_286 (Conv2D)         (None, 71, 71, 192)          138240    ['activation_285[0][0]']
#
#  batch_normalization_286 (B  (None, 71, 71, 192)          576       ['conv2d_286[0][0]']
#  atchNormalization)
#
#  activation_286 (Activation  (None, 71, 71, 192)          0         ['batch_normalization_286[0][0
#  )                                                                  ]']
#
#  max_pooling2d_13 (MaxPooli  (None, 35, 35, 192)          0         ['activation_286[0][0]']
#  ng2D)
#
#  conv2d_290 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_13[0][0]']
#
#  batch_normalization_290 (B  (None, 35, 35, 64)           192       ['conv2d_290[0][0]']
#  atchNormalization)
#
#  activation_290 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_290[0][0
#  )                                                                  ]']
#
#  conv2d_288 (Conv2D)         (None, 35, 35, 48)           9216      ['max_pooling2d_13[0][0]']
#
#  conv2d_291 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_290[0][0]']
#
#  batch_normalization_288 (B  (None, 35, 35, 48)           144       ['conv2d_288[0][0]']
#  atchNormalization)
#
#  batch_normalization_291 (B  (None, 35, 35, 96)           288       ['conv2d_291[0][0]']
#  atchNormalization)
#
#  activation_288 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_288[0][0
#  )                                                                  ]']
#
#  activation_291 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_291[0][0
#  )                                                                  ]']
#
#  average_pooling2d_27 (Aver  (None, 35, 35, 192)          0         ['max_pooling2d_13[0][0]']
#  agePooling2D)
#
#  conv2d_287 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_13[0][0]']
#
#  conv2d_289 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_288[0][0]']
#
#  conv2d_292 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_291[0][0]']
#
#  conv2d_293 (Conv2D)         (None, 35, 35, 32)           6144      ['average_pooling2d_27[0][0]']
#
#  batch_normalization_287 (B  (None, 35, 35, 64)           192       ['conv2d_287[0][0]']
#  atchNormalization)
#
#  batch_normalization_289 (B  (None, 35, 35, 64)           192       ['conv2d_289[0][0]']
#  atchNormalization)
#
#  batch_normalization_292 (B  (None, 35, 35, 96)           288       ['conv2d_292[0][0]']
#  atchNormalization)
#
#  batch_normalization_293 (B  (None, 35, 35, 32)           96        ['conv2d_293[0][0]']
#  atchNormalization)
#
#  activation_287 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_287[0][0
#  )                                                                  ]']
#
#  activation_289 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_289[0][0
#  )                                                                  ]']
#
#  activation_292 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_292[0][0
#  )                                                                  ]']
#
#  activation_293 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_293[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 35, 35, 256)          0         ['activation_287[0][0]',
#                                                                      'activation_289[0][0]',
#                                                                      'activation_292[0][0]',
#                                                                      'activation_293[0][0]']
#
#  conv2d_297 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_297 (B  (None, 35, 35, 64)           192       ['conv2d_297[0][0]']
#  atchNormalization)
#
#  activation_297 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_297[0][0
#  )                                                                  ]']
#
#  conv2d_295 (Conv2D)         (None, 35, 35, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_298 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_297[0][0]']
#
#  batch_normalization_295 (B  (None, 35, 35, 48)           144       ['conv2d_295[0][0]']
#  atchNormalization)
#
#  batch_normalization_298 (B  (None, 35, 35, 96)           288       ['conv2d_298[0][0]']
#  atchNormalization)
#
#  activation_295 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_295[0][0
#  )                                                                  ]']
#
#  activation_298 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_298[0][0
#  )                                                                  ]']
#
#  average_pooling2d_28 (Aver  (None, 35, 35, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_294 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_296 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_295[0][0]']
#
#  conv2d_299 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_298[0][0]']
#
#  conv2d_300 (Conv2D)         (None, 35, 35, 64)           16384     ['average_pooling2d_28[0][0]']
#
#  batch_normalization_294 (B  (None, 35, 35, 64)           192       ['conv2d_294[0][0]']
#  atchNormalization)
#
#  batch_normalization_296 (B  (None, 35, 35, 64)           192       ['conv2d_296[0][0]']
#  atchNormalization)
#
#  batch_normalization_299 (B  (None, 35, 35, 96)           288       ['conv2d_299[0][0]']
#  atchNormalization)
#
#  batch_normalization_300 (B  (None, 35, 35, 64)           192       ['conv2d_300[0][0]']
#  atchNormalization)
#
#  activation_294 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_294[0][0
#  )                                                                  ]']
#
#  activation_296 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_296[0][0
#  )                                                                  ]']
#
#  activation_299 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_299[0][0
#  )                                                                  ]']
#
#  activation_300 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_300[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 35, 35, 288)          0         ['activation_294[0][0]',
#                                                                      'activation_296[0][0]',
#                                                                      'activation_299[0][0]',
#                                                                      'activation_300[0][0]']
#
#  conv2d_304 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_304 (B  (None, 35, 35, 64)           192       ['conv2d_304[0][0]']
#  atchNormalization)
#
#  activation_304 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_304[0][0
#  )                                                                  ]']
#
#  conv2d_302 (Conv2D)         (None, 35, 35, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_305 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_304[0][0]']
#
#  batch_normalization_302 (B  (None, 35, 35, 48)           144       ['conv2d_302[0][0]']
#  atchNormalization)
#
#  batch_normalization_305 (B  (None, 35, 35, 96)           288       ['conv2d_305[0][0]']
#  atchNormalization)
#
#  activation_302 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_302[0][0
#  )                                                                  ]']
#
#  activation_305 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_305[0][0
#  )                                                                  ]']
#
#  average_pooling2d_29 (Aver  (None, 35, 35, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_301 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_303 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_302[0][0]']
#
#  conv2d_306 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_305[0][0]']
#
#  conv2d_307 (Conv2D)         (None, 35, 35, 64)           18432     ['average_pooling2d_29[0][0]']
#
#  batch_normalization_301 (B  (None, 35, 35, 64)           192       ['conv2d_301[0][0]']
#  atchNormalization)
#
#  batch_normalization_303 (B  (None, 35, 35, 64)           192       ['conv2d_303[0][0]']
#  atchNormalization)
#
#  batch_normalization_306 (B  (None, 35, 35, 96)           288       ['conv2d_306[0][0]']
#  atchNormalization)
#
#  batch_normalization_307 (B  (None, 35, 35, 64)           192       ['conv2d_307[0][0]']
#  atchNormalization)
#
#  activation_301 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_301[0][0
#  )                                                                  ]']
#
#  activation_303 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_303[0][0
#  )                                                                  ]']
#
#  activation_306 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_306[0][0
#  )                                                                  ]']
#
#  activation_307 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_307[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 35, 35, 288)          0         ['activation_301[0][0]',
#                                                                      'activation_303[0][0]',
#                                                                      'activation_306[0][0]',
#                                                                      'activation_307[0][0]']
#
#  conv2d_309 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_309 (B  (None, 35, 35, 64)           192       ['conv2d_309[0][0]']
#  atchNormalization)
#
#  activation_309 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_309[0][0
#  )                                                                  ]']
#
#  conv2d_310 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_309[0][0]']
#
#  batch_normalization_310 (B  (None, 35, 35, 96)           288       ['conv2d_310[0][0]']
#  atchNormalization)
#
#  activation_310 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_310[0][0
#  )                                                                  ]']
#
#  conv2d_308 (Conv2D)         (None, 17, 17, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_311 (Conv2D)         (None, 17, 17, 96)           82944     ['activation_310[0][0]']
#
#  batch_normalization_308 (B  (None, 17, 17, 384)          1152      ['conv2d_308[0][0]']
#  atchNormalization)
#
#  batch_normalization_311 (B  (None, 17, 17, 96)           288       ['conv2d_311[0][0]']
#  atchNormalization)
#
#  activation_308 (Activation  (None, 17, 17, 384)          0         ['batch_normalization_308[0][0
#  )                                                                  ]']
#
#  activation_311 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_311[0][0
#  )                                                                  ]']
#
#  max_pooling2d_14 (MaxPooli  (None, 17, 17, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 17, 17, 768)          0         ['activation_308[0][0]',
#                                                                      'activation_311[0][0]',
#                                                                      'max_pooling2d_14[0][0]']
#
#  conv2d_316 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_316 (B  (None, 17, 17, 128)          384       ['conv2d_316[0][0]']
#  atchNormalization)
#
#  activation_316 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_316[0][0
#  )                                                                  ]']
#
#  conv2d_317 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_316[0][0]']
#
#  batch_normalization_317 (B  (None, 17, 17, 128)          384       ['conv2d_317[0][0]']
#  atchNormalization)
#
#  activation_317 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_317[0][0
#  )                                                                  ]']
#
#  conv2d_313 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_318 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_317[0][0]']
#
#  batch_normalization_313 (B  (None, 17, 17, 128)          384       ['conv2d_313[0][0]']
#  atchNormalization)
#
#  batch_normalization_318 (B  (None, 17, 17, 128)          384       ['conv2d_318[0][0]']
#  atchNormalization)
#
#  activation_313 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_313[0][0
#  )                                                                  ]']
#
#  activation_318 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_318[0][0
#  )                                                                  ]']
#
#  conv2d_314 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_313[0][0]']
#
#  conv2d_319 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_318[0][0]']
#
#  batch_normalization_314 (B  (None, 17, 17, 128)          384       ['conv2d_314[0][0]']
#  atchNormalization)
#
#  batch_normalization_319 (B  (None, 17, 17, 128)          384       ['conv2d_319[0][0]']
#  atchNormalization)
#
#  activation_314 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_314[0][0
#  )                                                                  ]']
#
#  activation_319 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_319[0][0
#  )                                                                  ]']
#
#  average_pooling2d_30 (Aver  (None, 17, 17, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_312 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_315 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_314[0][0]']
#
#  conv2d_320 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_319[0][0]']
#
#  conv2d_321 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_30[0][0]']
#
#  batch_normalization_312 (B  (None, 17, 17, 192)          576       ['conv2d_312[0][0]']
#  atchNormalization)
#
#  batch_normalization_315 (B  (None, 17, 17, 192)          576       ['conv2d_315[0][0]']
#  atchNormalization)
#
#  batch_normalization_320 (B  (None, 17, 17, 192)          576       ['conv2d_320[0][0]']
#  atchNormalization)
#
#  batch_normalization_321 (B  (None, 17, 17, 192)          576       ['conv2d_321[0][0]']
#  atchNormalization)
#
#  activation_312 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_312[0][0
#  )                                                                  ]']
#
#  activation_315 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_315[0][0
#  )                                                                  ]']
#
#  activation_320 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_320[0][0
#  )                                                                  ]']
#
#  activation_321 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_321[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 17, 17, 768)          0         ['activation_312[0][0]',
#                                                                      'activation_315[0][0]',
#                                                                      'activation_320[0][0]',
#                                                                      'activation_321[0][0]']
#
#  conv2d_326 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_326 (B  (None, 17, 17, 160)          480       ['conv2d_326[0][0]']
#  atchNormalization)
#
#  activation_326 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_326[0][0
#  )                                                                  ]']
#
#  conv2d_327 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_326[0][0]']
#
#  batch_normalization_327 (B  (None, 17, 17, 160)          480       ['conv2d_327[0][0]']
#  atchNormalization)
#
#  activation_327 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_327[0][0
#  )                                                                  ]']
#
#  conv2d_323 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_328 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_327[0][0]']
#
#  batch_normalization_323 (B  (None, 17, 17, 160)          480       ['conv2d_323[0][0]']
#  atchNormalization)
#
#  batch_normalization_328 (B  (None, 17, 17, 160)          480       ['conv2d_328[0][0]']
#  atchNormalization)
#
#  activation_323 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_323[0][0
#  )                                                                  ]']
#
#  activation_328 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_328[0][0
#  )                                                                  ]']
#
#  conv2d_324 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_323[0][0]']
#
#  conv2d_329 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_328[0][0]']
#
#  batch_normalization_324 (B  (None, 17, 17, 160)          480       ['conv2d_324[0][0]']
#  atchNormalization)
#
#  batch_normalization_329 (B  (None, 17, 17, 160)          480       ['conv2d_329[0][0]']
#  atchNormalization)
#
#  activation_324 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_324[0][0
#  )                                                                  ]']
#
#  activation_329 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_329[0][0
#  )                                                                  ]']
#
#  average_pooling2d_31 (Aver  (None, 17, 17, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_322 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_325 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_324[0][0]']
#
#  conv2d_330 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_329[0][0]']
#
#  conv2d_331 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_31[0][0]']
#
#  batch_normalization_322 (B  (None, 17, 17, 192)          576       ['conv2d_322[0][0]']
#  atchNormalization)
#
#  batch_normalization_325 (B  (None, 17, 17, 192)          576       ['conv2d_325[0][0]']
#  atchNormalization)
#
#  batch_normalization_330 (B  (None, 17, 17, 192)          576       ['conv2d_330[0][0]']
#  atchNormalization)
#
#  batch_normalization_331 (B  (None, 17, 17, 192)          576       ['conv2d_331[0][0]']
#  atchNormalization)
#
#  activation_322 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_322[0][0
#  )                                                                  ]']
#
#  activation_325 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_325[0][0
#  )                                                                  ]']
#
#  activation_330 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_330[0][0
#  )                                                                  ]']
#
#  activation_331 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_331[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 17, 17, 768)          0         ['activation_322[0][0]',
#                                                                      'activation_325[0][0]',
#                                                                      'activation_330[0][0]',
#                                                                      'activation_331[0][0]']
#
#  conv2d_336 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_336 (B  (None, 17, 17, 160)          480       ['conv2d_336[0][0]']
#  atchNormalization)
#
#  activation_336 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_336[0][0
#  )                                                                  ]']
#
#  conv2d_337 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_336[0][0]']
#
#  batch_normalization_337 (B  (None, 17, 17, 160)          480       ['conv2d_337[0][0]']
#  atchNormalization)
#
#  activation_337 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_337[0][0
#  )                                                                  ]']
#
#  conv2d_333 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_338 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_337[0][0]']
#
#  batch_normalization_333 (B  (None, 17, 17, 160)          480       ['conv2d_333[0][0]']
#  atchNormalization)
#
#  batch_normalization_338 (B  (None, 17, 17, 160)          480       ['conv2d_338[0][0]']
#  atchNormalization)
#
# ...
#
#  conv2d_358 (Conv2D)         (None, 8, 8, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_360 (B  (None, 8, 8, 384)            1152      ['conv2d_360[0][0]']
#  atchNormalization)
#
#  batch_normalization_361 (B  (None, 8, 8, 384)            1152      ['conv2d_361[0][0]']
#  atchNormalization)
#
#  batch_normalization_364 (B  (None, 8, 8, 384)            1152      ['conv2d_364[0][0]']
#  atchNormalization)
#
#  batch_normalization_365 (B  (None, 8, 8, 384)            1152      ['conv2d_365[0][0]']
#  atchNormalization)
#
#  conv2d_366 (Conv2D)         (None, 8, 8, 192)            245760    ['average_pooling2d_34[0][0]']
#
#  batch_normalization_358 (B  (None, 8, 8, 320)            960       ['conv2d_358[0][0]']
#  atchNormalization)
#
#  activation_360 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_360[0][0
#  )                                                                  ]']
#
#  activation_361 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_361[0][0
#  )                                                                  ]']
#
#  activation_364 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_364[0][0
#  )                                                                  ]']
#
#  activation_365 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_365[0][0
#  )                                                                  ]']
#
#  batch_normalization_366 (B  (None, 8, 8, 192)            576       ['conv2d_366[0][0]']
#  atchNormalization)
#
#  activation_358 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_358[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 8, 8, 768)            0         ['activation_360[0][0]',
#                                                                      'activation_361[0][0]']
#
#  concatenate_6 (Concatenate  (None, 8, 8, 768)            0         ['activation_364[0][0]',
#  )                                                                   'activation_365[0][0]']
#
#  activation_366 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_366[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 8, 8, 2048)           0         ['activation_358[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_6[0][0]',
#                                                                      'activation_366[0][0]']
#
#  conv2d_371 (Conv2D)         (None, 8, 8, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_371 (B  (None, 8, 8, 448)            1344      ['conv2d_371[0][0]']
#  atchNormalization)
#
#  activation_371 (Activation  (None, 8, 8, 448)            0         ['batch_normalization_371[0][0
#  )                                                                  ]']
#
#  conv2d_368 (Conv2D)         (None, 8, 8, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_372 (Conv2D)         (None, 8, 8, 384)            1548288   ['activation_371[0][0]']
#
#  batch_normalization_368 (B  (None, 8, 8, 384)            1152      ['conv2d_368[0][0]']
#  atchNormalization)
#
#  batch_normalization_372 (B  (None, 8, 8, 384)            1152      ['conv2d_372[0][0]']
#  atchNormalization)
#
#  activation_368 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_368[0][0
#  )                                                                  ]']
#
#  activation_372 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_372[0][0
#  )                                                                  ]']
#
#  conv2d_369 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_368[0][0]']
#
#  conv2d_370 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_368[0][0]']
#
#  conv2d_373 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_372[0][0]']
#
#  conv2d_374 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_372[0][0]']
#
#  average_pooling2d_35 (Aver  (None, 8, 8, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_367 (Conv2D)         (None, 8, 8, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_369 (B  (None, 8, 8, 384)            1152      ['conv2d_369[0][0]']
#  atchNormalization)
#
#  batch_normalization_370 (B  (None, 8, 8, 384)            1152      ['conv2d_370[0][0]']
#  atchNormalization)
#
#  batch_normalization_373 (B  (None, 8, 8, 384)            1152      ['conv2d_373[0][0]']
#  atchNormalization)
#
#  batch_normalization_374 (B  (None, 8, 8, 384)            1152      ['conv2d_374[0][0]']
#  atchNormalization)
#
#  conv2d_375 (Conv2D)         (None, 8, 8, 192)            393216    ['average_pooling2d_35[0][0]']
#
#  batch_normalization_367 (B  (None, 8, 8, 320)            960       ['conv2d_367[0][0]']
#  atchNormalization)
#
#  activation_369 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_369[0][0
#  )                                                                  ]']
#
#  activation_370 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_370[0][0
#  )                                                                  ]']
#
#  activation_373 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_373[0][0
#  )                                                                  ]']
#
#  activation_374 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_374[0][0
#  )                                                                  ]']
#
#  batch_normalization_375 (B  (None, 8, 8, 192)            576       ['conv2d_375[0][0]']
#  atchNormalization)
#
#  activation_367 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_367[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 8, 8, 768)            0         ['activation_369[0][0]',
#                                                                      'activation_370[0][0]']
#
#  concatenate_7 (Concatenate  (None, 8, 8, 768)            0         ['activation_373[0][0]',
#  )                                                                   'activation_374[0][0]']
#
#  activation_375 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_375[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 8, 8, 2048)           0         ['activation_367[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_7[0][0]',
#                                                                      'activation_375[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['mixed10[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 2049000   ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23851784 (90.99 MB)
# Trainable params: 23817352 (90.86 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________
# None
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1/1 - 18s - loss: 7.0675 - accuracy: 0.0000e+00 - 18s/epoch - 18s/step
# Epoch 2/15
# 1/1 - 3s - loss: 3.0156 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 3/15
# 1/1 - 3s - loss: 0.1679 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 4/15
# 1/1 - 3s - loss: 0.0196 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 5/15
# 1/1 - 3s - loss: 0.0028 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 6/15
# 1/1 - 3s - loss: 5.6127e-04 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 7/15
# 1/1 - 3s - loss: 1.7442e-04 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 8/15
# 1/1 - 3s - loss: 7.3975e-05 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 9/15
# 1/1 - 3s - loss: 3.8002e-05 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 10/15
# 1/1 - 3s - loss: 2.2315e-05 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 11/15
# 1/1 - 3s - loss: 1.4782e-05 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 12/15
# 1/1 - 3s - loss: 1.0848e-05 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 13/15
# 1/1 - 3s - loss: 8.5353e-06 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 14/15
# 1/1 - 3s - loss: 7.2002e-06 - accuracy: 1.0000 - 3s/epoch - 3s/step
# Epoch 15/15
# 1/1 - 3s - loss: 6.2704e-06 - accuracy: 1.0000 - 3s/epoch - 3s/step

# %%
#tensorflow hub

x=tf.random.normal(shape=(5,299,299,3))
y=tf.constant([0,1,2,3,4])

url = "https://tfhub.dev/google/imagenet/inception_v3/feature_vector/4"

#the below doesnt have fully connected layers
base_model=hub.KerasLayer(url,input_shape=(299,299,3))

#fine tuning
base_model.trainable=False
model=keras.Sequential([
        base_model,
        layers.Dense(128, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(10),
])
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"],
)

model.fit(x, y, batch_size=32, epochs=15, verbose=2)
# Out:
# Epoch 1/15
# 1/1 - 5s - loss: 2.5427 - accuracy: 0.0000e+00 - 5s/epoch - 5s/step
# Epoch 2/15
# 1/1 - 1s - loss: 2.0348 - accuracy: 0.4000 - 660ms/epoch - 660ms/step
# Epoch 3/15
# 1/1 - 1s - loss: 1.8139 - accuracy: 0.2000 - 677ms/epoch - 677ms/step
# Epoch 4/15
# 1/1 - 1s - loss: 1.6750 - accuracy: 0.4000 - 660ms/epoch - 660ms/step
# Epoch 5/15
# 1/1 - 1s - loss: 1.5586 - accuracy: 0.2000 - 657ms/epoch - 657ms/step
# Epoch 6/15
# 1/1 - 1s - loss: 1.4319 - accuracy: 0.8000 - 671ms/epoch - 671ms/step
# Epoch 7/15
# 1/1 - 1s - loss: 1.3163 - accuracy: 0.8000 - 660ms/epoch - 660ms/step
# Epoch 8/15
# 1/1 - 1s - loss: 1.2164 - accuracy: 0.8000 - 670ms/epoch - 670ms/step
# Epoch 9/15
# 1/1 - 1s - loss: 1.1286 - accuracy: 1.0000 - 663ms/epoch - 663ms/step
# Epoch 10/15
# 1/1 - 1s - loss: 1.0436 - accuracy: 1.0000 - 671ms/epoch - 671ms/step
# Epoch 11/15
# 1/1 - 1s - loss: 0.9741 - accuracy: 1.0000 - 669ms/epoch - 669ms/step
# Epoch 12/15
# 1/1 - 1s - loss: 0.9055 - accuracy: 1.0000 - 670ms/epoch - 670ms/step
# Epoch 13/15
# 1/1 - 1s - loss: 0.8335 - accuracy: 1.0000 - 663ms/epoch - 663ms/step
# Epoch 14/15
# 1/1 - 1s - loss: 0.7648 - accuracy: 1.0000 - 663ms/epoch - 663ms/step
# Epoch 15/15
# 1/1 - 1s - loss: 0.7032 - accuracy: 1.0000 - 829ms/epoch - 829ms/step
